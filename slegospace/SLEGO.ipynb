# %% [markdown]
# <a href="https://colab.research.google.com/github/alanntl/SELGO-LITE/blob/alanntl/SLEGO_LITE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SLEGO Project: UNSW CSE PhD Research - Alan Siu Lung Ng
# https://github.com/alanntl/SLEGO-Project

# %%
# First, import the environment_setup module
import environment_setup

# Run the environment setup
config = environment_setup.setup_environment()
# Out:
# Running in GitHub Codespaces environment.
# No directory changes detected; no update necessary.
# Requirement already satisfied: panel in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: jupyter_bokeh in /usr/local/python/3.10.13/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 2)) (4.0.5)
# Requirement already satisfied: openml in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 3)) (0.13.0)
# Requirement already satisfied: ucimlrepo in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 4)) (0.0.7)
# Requirement already satisfied: openai==1.19.0 in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 5)) (1.19.0)
# Requirement already satisfied: PyPDF2 in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: pdfkit in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: autogluon in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: arxiv in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: python-docx in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 10)) (1.1.2)
# Requirement already satisfied: openpyxl in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 11)) (3.1.5)
# Requirement already satisfied: pytesseract in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 12)) (0.3.10)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 13)) (10.4.0)
# Requirement already satisfied: sweetviz in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 14)) (2.3.1)
# Requirement already satisfied: vectorbt in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 15)) (0.26.1)
# Requirement already satisfied: quantstats in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 16)) (0.0.62)
# Requirement already satisfied: autokeras in /home/codespace/.local/lib/python3.10/site-packages (from -r /workspaces/SELGO-LITE/requirements.txt (line 17)) (2.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: param<3.0,>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2024.6.0)
# Requirement already satisfied: markdown in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (3.6)
# Requirement already satisfied: markdown-it-py in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: linkify-it-py in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: bleach in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: pandas>=1.2 in /home/codespace/.local/lib/python3.10/site-packages (from panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: ipywidgets==8.* in /home/codespace/.local/lib/python3.10/site-packages (from jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: Jinja2>=2.9 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: numpy>=1.16 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (24.1)
# Requirement already satisfied: PyYAML>=3.10 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: comm>=0.1.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (3.0.11)
# Requirement already satisfied: liac-arff>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: xmltodict in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (0.13.0)
# Requirement already satisfied: scikit-learn>=0.18 in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: python-dateutil in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: scipy>=0.13.3 in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: minio in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (7.2.7)
# Requirement already satisfied: pyarrow in /home/codespace/.local/lib/python3.10/site-packages (from openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (17.0.0)
# Requirement already satisfied: certifi>=2020.12.5 in /home/codespace/.local/lib/python3.10/site-packages (from ucimlrepo->-r /workspaces/SELGO-LITE/requirements.txt (line 4)) (2024.7.4)
# Requirement already satisfied: autogluon.core==1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: autogluon.features==1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: autogluon.tabular==1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: autogluon.multimodal==1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: autogluon.timeseries==1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: networkx<4,>=3.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.3)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.9.1)
# Requirement already satisfied: boto3<2,>=1.10 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.34.145)
# Requirement already satisfied: autogluon.common==1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: ray<2.11,>=2.10.0 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.2.7)
# Requirement already satisfied: torch<2.4,>=2.2 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.3.1+cpu)
# Requirement already satisfied: lightning<2.4,>=2.2 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.3.3)
# Requirement already satisfied: transformers<4.41.0,>=4.38.0 in /home/codespace/.local/lib/python3.10/site-packages (from transformers[sentencepiece]<4.41.0,>=4.38.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.39.3)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.9.16)
# Requirement already satisfied: torchvision<0.19.0,>=0.16.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: tensorboard<3,>=2.9 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.17.0)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: xgboost<2.1,>=1.6 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.7.15)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: catboost<1.3,>=1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.2.5)
# Requirement already satisfied: joblib<2,>=1.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: pytorch-lightning<2.4,>=2.2 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.3.3)
# Requirement already satisfied: gluonts==0.15.1 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.15.1)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.10.6)
# Requirement already satisfied: optimum<1.19,>=1.17 in /home/codespace/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.common==1.1.1->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (5.9.8)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from autogluon.common==1.1.1->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (71.0.3)
# Requirement already satisfied: toolz~=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from gluonts==0.15.1->autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: feedparser~=6.0.10 in /home/codespace/.local/lib/python3.10/site-packages (from arxiv->-r /workspaces/SELGO-LITE/requirements.txt (line 9)) (6.0.11)
# Requirement already satisfied: lxml>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from python-docx->-r /workspaces/SELGO-LITE/requirements.txt (line 10)) (5.2.2)
# Requirement already satisfied: et-xmlfile in /home/codespace/.local/lib/python3.10/site-packages (from openpyxl->-r /workspaces/SELGO-LITE/requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: importlib-resources>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from sweetviz->-r /workspaces/SELGO-LITE/requirements.txt (line 14)) (6.4.0)
# Requirement already satisfied: plotly>=4.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (5.22.0)
# Requirement already satisfied: dill in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (0.3.8)
# Requirement already satisfied: dateparser in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (1.2.0)
# Requirement already satisfied: imageio in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (2.34.2)
# Requirement already satisfied: schedule in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (1.2.2)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (2024.1)
# Requirement already satisfied: mypy-extensions in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (1.0.0)
# Requirement already satisfied: numba<0.57.0,>=0.56.0 in /home/codespace/.local/lib/python3.10/site-packages (from vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (0.56.4)
# Requirement already satisfied: seaborn>=0.9.0 in /home/codespace/.local/lib/python3.10/site-packages (from quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (0.13.2)
# Requirement already satisfied: tabulate>=0.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in /home/codespace/.local/lib/python3.10/site-packages (from quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (0.2.40)
# Requirement already satisfied: keras-tuner>=1.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (1.4.7)
# Requirement already satisfied: keras-nlp>=0.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.14.0)
# Requirement already satisfied: keras>=3.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (3.4.1)
# Requirement already satisfied: dm-tree in /home/codespace/.local/lib/python3.10/site-packages (from autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.1.8)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: sgmllib3k in /home/codespace/.local/lib/python3.10/site-packages (from feedparser~=6.0.10->arxiv->-r /workspaces/SELGO-LITE/requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: absl-py in /home/codespace/.local/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: rich in /home/codespace/.local/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (13.7.1)
# Requirement already satisfied: namex in /home/codespace/.local/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.0.8)
# Requirement already satisfied: h5py in /home/codespace/.local/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (3.11.0)
# Requirement already satisfied: optree in /home/codespace/.local/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: ml-dtypes in /home/codespace/.local/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: regex in /home/codespace/.local/lib/python3.10/site-packages (from keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (2024.5.15)
# Requirement already satisfied: kagglehub in /home/codespace/.local/lib/python3.10/site-packages (from keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.2.8)
# Requirement already satisfied: tensorflow-text in /home/codespace/.local/lib/python3.10/site-packages (from keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (2.17.0)
# Requirement already satisfied: kt-legacy in /home/codespace/.local/lib/python3.10/site-packages (from keras-tuner>=1.4.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/codespace/.local/lib/python3.10/site-packages (from numba<0.57.0,>=0.56.0->vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (0.39.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from plotly>=4.12.0->vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (8.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai==1.19.0->-r /workspaces/SELGO-LITE/requirements.txt (line 5)) (2.20.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn>=0.18->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (1.1)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.10/site-packages (from bleach->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tzlocal in /home/codespace/.local/lib/python3.10/site-packages (from dateparser->vectorbt->-r /workspaces/SELGO-LITE/requirements.txt (line 15)) (5.2)
# Requirement already satisfied: uc-micro-py in /home/codespace/.local/lib/python3.10/site-packages (from linkify-it-py->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/codespace/.local/lib/python3.10/site-packages (from markdown-it-py->panel->-r /workspaces/SELGO-LITE/requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: argon2-cffi in /home/codespace/.local/lib/python3.10/site-packages (from minio->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: pycryptodome in /home/codespace/.local/lib/python3.10/site-packages (from minio->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats->-r /workspaces/SELGO-LITE/requirements.txt (line 16)) (2.5)
# Requirement already satisfied: botocore<1.35.0,>=1.34.145 in /home/codespace/.local/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.34.145)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/codespace/.local/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: graphviz in /home/codespace/.local/lib/python3.10/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.20.3)
# Requirement already satisfied: datasets>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.20.0)
# Requirement already satisfied: xxhash in /home/codespace/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.4.1)
# Requirement already satisfied: multiprocess in /home/codespace/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /home/codespace/.local/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2024.5.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/codespace/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.24.0)
# Requirement already satisfied: pip in /home/codespace/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (24.1.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/codespace/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /home/codespace/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.5.54)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/codespace/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.0.3)
# Requirement already satisfied: spacy<4 in /home/codespace/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.7.5)
# Requirement already satisfied: future in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: cloudpickle in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: py4j in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.10.9.7)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: stack-data in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.19.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /home/codespace/.local/lib/python3.10/site-packages (from lightning<2.4,>=2.2->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.11.5)
# Requirement already satisfied: window-ops in /home/codespace/.local/lib/python3.10/site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (5.2.0)
# Requirement already satisfied: click in /home/codespace/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/codespace/.local/lib/python3.10/site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.9.3)
# Requirement already satisfied: colorama in /home/codespace/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: model-index in /home/codespace/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.1.11)
# Requirement already satisfied: opendatalab in /home/codespace/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.0.10)
# Requirement already satisfied: coloredlogs in /home/codespace/.local/lib/python3.10/site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (15.0.1)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.10/site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.13.0)
# Requirement already satisfied: onnx in /home/codespace/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.16.1)
# Requirement already satisfied: onnxruntime>=1.11.0 in /home/codespace/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.18.1)
# Requirement already satisfied: protobuf>=3.20.1 in /home/codespace/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.25.3)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.15.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.0.8)
# Requirement already satisfied: aiosignal in /home/codespace/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: frozenlist in /home/codespace/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.4.1)
# Requirement already satisfied: aiohttp>=3.7 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.9.5)
# Requirement already satisfied: aiohttp-cors in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: colorful in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.3.14)
# Requirement already satisfied: opencensus in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: smart-open in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (7.0.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (20.26.3)
# Requirement already satisfied: grpcio>=1.42.0 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.65.1)
# Requirement already satisfied: tensorboardX>=1.9 in /home/codespace/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.6.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2024.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /home/codespace/.local/lib/python3.10/site-packages (from statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.14.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: safetensors in /home/codespace/.local/lib/python3.10/site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/codespace/.local/lib/python3.10/site-packages (from transformers<4.41.0,>=4.38.0->transformers[sentencepiece]<4.41.0,>=4.38.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.15.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /home/codespace/.local/lib/python3.10/site-packages (from transformers[sentencepiece]<4.41.0,>=4.38.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/codespace/.local/lib/python3.10/site-packages (from argon2-cffi->minio->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: tensorflow<2.18,>=2.17.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (2.17.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.0.3)
# Requirement already satisfied: pyarrow-hotfix in /home/codespace/.local/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/codespace/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: flatbuffers in /home/codespace/.local/lib/python3.10/site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (24.3.25)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.12.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/codespace/.local/lib/python3.10/site-packages (from statsmodels>=0.13.2->statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.1->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.5.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.37.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/codespace/.local/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: cffi>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/codespace/.local/lib/python3.10/site-packages (from coloredlogs->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (10.0)
# Requirement already satisfied: ordered-set in /home/codespace/.local/lib/python3.10/site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /home/codespace/.local/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.19.1)
# Requirement already satisfied: openxlab in /home/codespace/.local/lib/python3.10/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.0.11)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh->-r /workspaces/SELGO-LITE/requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from sympy->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/codespace/.local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17.0->tensorflow-text->keras-nlp>=0.8.0->autokeras->-r /workspaces/SELGO-LITE/requirements.txt (line 17)) (0.43.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml->-r /workspaces/SELGO-LITE/requirements.txt (line 3)) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/codespace/.local/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.63.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/codespace/.local/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /home/codespace/.local/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (2.32.0)
# Requirement already satisfied: language-data>=1.2 in /home/codespace/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/codespace/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/codespace/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/codespace/.local/lib/python3.10/site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/codespace/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (4.9)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/codespace/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/codespace/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.1->autogluon->-r /workspaces/SELGO-LITE/requirements.txt (line 8)) (0.6.0)
# Working directory changed to: /workspaces/SELGO-LITE/slegospace

# %% [markdown]
# # SLEGO APP

# %%
import slegoapp
display(config)
# Kill all existing servers
pn.state.kill_all_servers()

# Create and run the new app
slego_app = slegoapp.SLEGOApp(config)
slego_app.run()
# Out:
# {'drive_mainfolder': '/workspaces/SELGO-LITE',
#  'drive_folder': '/workspaces/',
#  'repo_url': 'https://github.com/alanntl/SELGO-LITE.git',
#  'slego_env': '/workspaces//slego_env_v0_0_1',
#  'requirements_file': '/workspaces/SELGO-LITE/requirements.txt',
#  'folder_path': '/workspaces/SELGO-LITE/slegospace',
#  'dataspace': '/workspaces/SELGO-LITE/slegospace/dataspace',
#  'recordspace': '/workspaces/SELGO-LITE/slegospace/recordspace',
#  'functionspace': '/workspaces/SELGO-LITE/slegospace/functionspace',
#  'knowledgespace': '/workspaces/SELGO-LITE/slegospace/knowledgespace'}
