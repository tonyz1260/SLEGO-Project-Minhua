# %% [markdown]
# <a href="https://colab.research.google.com/github/alanntl/SELGO-LITE/blob/alanntl/SLEGO_LITE_APR26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SLEGO Project: UNSW CSE PhD Research - Alan Siu Lung Ng

# %% [markdown]
# # Connect this Notebook to your GoogleDrive
# paste this code on terminal if you wanna run colab using local runtime:
#
#   jupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8888 --NotebookApp.port_retries=0

# %%
# %%time
import sys

# Function to check if running in Google Colab
def is_colab_runtime():
    return 'google.colab' in sys.modules

# Define main folder path based on runtime environment
if is_colab_runtime():
    print("This is running in Google Colab.")
    drive_mainfolder = '/content/drive/MyDrive/SLEGO'
    # Import necessary Colab modules here
    from google.colab import drive
    from google.colab import files
    # Mount Google Drive
    drive.mount('/content/drive', force_remount=True)
else:
    print("This is running in a local or other remote runtime.")
    gmailaccount = 'xxxxxx@gmail.com'
    drive_mainfolder = f"/Users/an/Library/CloudStorage/GoogleDrive-{gmailaccount}/My Drive/SLEGO"
    drive_folder= f"/Users/an/Library/CloudStorage/GoogleDrive-{gmailaccount}/My Drive/"

# This %%time magic command only works in IPython/Jupyter environments, and its placement should be at the start of a cell.
# If needed for timing in a script, use the time module or other Python profiling tools.
# Out:
# This is running in a local or other remote runtime.
# CPU times: user 402 µs, sys: 136 µs, total: 538 µs
# Wall time: 491 µs

# %% [markdown]
# # Clone SLEGO repo

# %%
# %%time
import os
import sys
from IPython.display import clear_output
import subprocess

# Path to your repository
repo_path = drive_mainfolder
repo_url = 'https://github.com/alanntl/SELGO-LITE.git'

# Function to run subprocess commands with error handling
def run_command(command, check=True, **kwargs):
    try:
        subprocess.run(command, check=check, **kwargs)
    except subprocess.CalledProcessError as e:
        print(f"Error running command {' '.join(command)}: {e}")
        return None
    return True

# Ensure the repository path exists
if not os.path.exists(repo_path):
    if run_command(['git', 'clone', repo_url, repo_path]):
        print("Repository cloned.")
else:
    # Change to the repository directory
    os.chdir(repo_path)

    # Fetch latest changes from the repository
    if run_command(['git', 'fetch']):
        # Check for new or changed directories
        result = subprocess.run(['git', 'diff', '--name-only', 'HEAD', 'origin/master'], capture_output=True, text=True)
        changed_files = result.stdout.splitlines()
        directory_changes = any(os.path.dirname(f) for f in changed_files)

        if directory_changes:
            # If there are directory changes, pull the updates
            if run_command(['git', 'pull']):
                print("Repository updated with new directory changes.")
        else:
            print("No directory changes detected; no update necessary.")
# Out:
# Error running command git fetch: Command '['git', 'fetch']' returned non-zero exit status 1.
# CPU times: user 1.82 ms, sys: 5.67 ms, total: 7.49 ms
# Wall time: 1.13 s
# fatal: bad object refs/remotes/origin/alanntl (1)
# error: https://github.com/alanntl/SELGO-LITE.git did not send all necessary objects

# %% [markdown]
# # Setup virtural library

# %%
# %%time
import os
import sys

# Define the path to the virtual environment
slego_env = f"{drive_folder}/slego_env_v0_0_1"
requirements_file = f"{drive_mainfolder}/requirements.txt"

# Check if the virtual environment directory does not exist
if not os.path.exists(slego_env):
    # Install virtualenv if it's not installed
    # !pip install virtualenv
    # Create the virtual environment
    # !virtualenv "{slego_env}"

    # Activate the virtual environment
    # !source "{slego_env}/bin/activate"

    # Check if the requirements file exists
    if os.path.exists(requirements_file):
        # Install the requirements from the file
        # !pip install -r "{requirements_file}"

# Append the path to sys.path
if is_colab_runtime():
    sys.path.append(f"{slego_env}/lib/python3.10/site-packages")
else:
    # !pip install -r "{requirements_file}"
# Out:
# Requirement already satisfied: panel in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: openml in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (0.14.2)
# Requirement already satisfied: scikit-learn in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: ucimlrepo in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 4)) (0.0.6)
# Requirement already satisfied: openai==1.19.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (1.19.0)
# Requirement already satisfied: PyPDF2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: pdfkit in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: autogluon in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: arxiv in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: python-docx in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: openpyxl in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: yfinance in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (0.2.38)
# Requirement already satisfied: pytesseract in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 13)) (0.3.10)
# Requirement already satisfied: Pillow in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 14)) (10.3.0)
# Requirement already satisfied: sweetviz in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 15)) (2.3.1)
# Requirement already satisfied: vectorbt in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (0.26.1)
# Requirement already satisfied: quantstats in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 17)) (0.0.62)
# Requirement already satisfied: autokeras in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pycaret in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (2.2.2)
# Requirement already satisfied: autoviz in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from -r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (0.1.802)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (2.7.1)
# Requirement already satisfied: sniffio in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (4.11.0)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: param<3.0,>=2.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: pyviz-comms>=2.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2024.4.0)
# Requirement already satisfied: markdown in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (3.6)
# Requirement already satisfied: markdown-it-py in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: linkify-it-py in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: requests in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: bleach in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: pandas>=1.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: liac-arff>=2.4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: xmltodict in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: python-dateutil in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: scipy>=0.13.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: numpy>=1.6.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (1.23.5)
# Requirement already satisfied: minio in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (7.2.6)
# Requirement already satisfied: pyarrow in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (15.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from scikit-learn->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from scikit-learn->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: autogluon.core==1.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: autogluon.features==1.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: autogluon.tabular==1.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: autogluon.multimodal==1.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: autogluon.timeseries==1.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: networkx<4,>=3.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (3.3)
# Requirement already satisfied: matplotlib in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (3.7.4)
# Requirement already satisfied: boto3<2,>=1.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.34.92)
# Requirement already satisfied: autogluon.common==1.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: ray<2.11,>=2.10.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.2.7)
# Requirement already satisfied: torch<2.2,>=2.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.1.4)
# Requirement already satisfied: transformers<4.39.0,>=4.38.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.38.2)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.9.16)
# Requirement already satisfied: torchvision<0.17.0,>=0.16.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.16.2)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: tensorboard<3,>=2.9 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.16.2)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: xgboost<2.1,>=1.6 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.6.2)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.7.14)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: catboost<1.2,>=1.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.1.4)
# Requirement already satisfied: gluonts<0.14.4,>=0.14.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.14.3)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (3.10.1)
# Requirement already satisfied: optimum<1.19,>=1.17 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (5.9.8)
# Requirement already satisfied: setuptools in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (68.2.2)
# Requirement already satisfied: feedparser==6.0.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from arxiv->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 9)) (6.0.10)
# Requirement already satisfied: sgmllib3k in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from feedparser==6.0.10->arxiv->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from requests->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from requests->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from requests->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from requests->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: lxml>=3.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from python-docx->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 10)) (5.2.1)
# Requirement already satisfied: et-xmlfile in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from openpyxl->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (1.1)
# Requirement already satisfied: packaging>=21.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pytesseract->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 13)) (24.0)
# Requirement already satisfied: importlib-resources>=1.2.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from sweetviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 15)) (6.4.0)
# Requirement already satisfied: plotly>=4.12.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (5.21.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (8.1.2)
# Requirement already satisfied: dill in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (0.3.8)
# Requirement already satisfied: dateparser in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: imageio in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (2.34.1)
# Requirement already satisfied: schedule in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: mypy-extensions in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: numba<0.57.0,>=0.56.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (0.56.4)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from quantstats->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 17)) (0.12.2)
# Requirement already satisfied: tabulate>=0.8.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from quantstats->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: keras-tuner>=1.4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (1.4.7)
# Requirement already satisfied: keras-nlp>=0.8.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.9.3)
# Requirement already satisfied: keras>=3.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (3.3.2)
# Requirement already satisfied: dm-tree in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.1.8)
# Requirement already satisfied: IPython in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (8.24.0)
# Requirement already satisfied: yellowbrick>=1.0.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (1.5)
# Requirement already satisfied: wordcloud in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (1.9.3)
# Requirement already satisfied: textblob in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.18.0.post0)
# Requirement already satisfied: cufflinks>=0.17.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.17.3)
# Requirement already satisfied: umap-learn in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.5.6)
# Requirement already satisfied: pyLDAvis in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (3.4.0)
# Requirement already satisfied: gensim in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (4.3.2)
# Requirement already satisfied: spacy in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (3.7.4)
# Requirement already satisfied: mlxtend in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.23.1)
# Requirement already satisfied: pyod in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (1.1.3)
# Requirement already satisfied: pandas-profiling>=2.8.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (3.6.6)
# Requirement already satisfied: kmodes>=0.10.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.12.2)
# Requirement already satisfied: mlflow in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (2.12.1)
# Requirement already satisfied: imbalanced-learn>=0.7.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.12.2)
# Requirement already satisfied: scikit-plot in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.3.7)
# Requirement already satisfied: emoji in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autoviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (2.11.1)
# Requirement already satisfied: fsspec>=0.8.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autoviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (2024.3.1)
# Requirement already satisfied: pandas-dq>=1.29 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autoviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (1.29)
# Requirement already satisfied: pyamg in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autoviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (5.1.0)
# Requirement already satisfied: statsmodels in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autoviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (0.14.2)
# Requirement already satisfied: xlrd in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from autoviz->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 20)) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (2.5)
# Requirement already satisfied: contourpy>=1.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from bokeh<3.5.0,>=3.4.0->panel->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 1)) (6.4)
# Requirement already satisfied: graphviz in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from catboost<1.2,>=1.1->autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.20.3)
# Requirement already satisfied: six in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from catboost<1.2,>=1.1->autogluon.tabular[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from cufflinks>=0.17.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: webencodings in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from html5lib>=1.1->yfinance->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: httpcore==1.* in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.19.0->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: decorator in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (2.17.2)
# Requirement already satisfied: stack-data in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ipywidgets>=7.0.0->vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ipywidgets>=7.0.0->vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ipywidgets>=7.0.0->vectorbt->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 16)) (3.0.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.1.5)
# Requirement already satisfied: absl-py in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (2.1.0)
# Requirement already satisfied: rich in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (13.7.1)
# Requirement already satisfied: namex in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.0.8)
# Requirement already satisfied: h5py in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (3.11.0)
# Requirement already satisfied: optree in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.11.0)
# Requirement already satisfied: ml-dtypes in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras>=3.0.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.4.0)
# Requirement already satisfied: keras-core in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras-nlp>=0.8.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.1.7)
# Requirement already satisfied: regex in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras-nlp>=0.8.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (2024.4.16)
# Requirement already satisfied: kagglehub in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras-nlp>=0.8.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (0.2.4)
# Requirement already satisfied: kt-legacy in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from keras-tuner>=1.4.0->autokeras->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 18)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.51.0)
# ...
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (20.26.0)
# Requirement already satisfied: grpcio>=1.42.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.62.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2024.4.24)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.1.4)
# Requirement already satisfied: safetensors in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from transformers<4.39.0,>=4.38.0->transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.15.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from argon2-cffi->minio->openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from stack-data->IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from stack-data->IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from stack-data->IPython->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.2.2)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (0.12.4)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (1.11.2)
# Requirement already satisfied: typeguard<5,>=4.1.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (4.2.1)
# Requirement already satisfied: imagehash==4.3.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (4.3.1)
# Requirement already satisfied: dacite>=1.8 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.0.3)
# Requirement already satisfied: pyarrow-hotfix in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (5.0.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->pycaret->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: flatbuffers in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (24.3.25)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.2.1)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: cffi>=1.0.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from coloredlogs->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (10.0)
# Requirement already satisfied: ordered-set in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: openxlab in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.0.11)
# Requirement already satisfied: mpmath>=0.19 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from sympy->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: pycparser in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 2)) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (2.29.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/an/anaconda3/envs/slegolite310/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon->-r /Users/an/Library/CloudStorage/GoogleDrive-alann5157@gmail.com/My Drive/SLEGO/requirements.txt (line 8)) (0.6.0)
# CPU times: user 57.2 ms, sys: 21.2 ms, total: 78.4 ms
# Wall time: 6.16 s

# %% [markdown]
# # Setup the app foldersystem for slego

# %%
# This will prompt for authorization and mount your Google Drive.
if is_colab_runtime()==True:
    drive.mount('/content/drive', force_remount=True)

folder_path = f'{drive_mainfolder}/slegospace'

# Now you can reference subfolders and files relative to the top-level folder
dataspace = '/dataspace/'  # This is equivalent to '/content/drive/MyDrive/SLEGO/slegospace/dataspace'
recordspace = '/recordspace/'  # Equivalent to '/content/drive/MyDrive/SLEGO/slegospace/recordspace'
functionspace = '/functionspace/'  # Equivalent to '/content/drive/MyDrive/SLEGO/slegospace/functionspace'
knowledgespace = '/knowledgespace/'  # Equivalent to '/content/drive/MyDrive/SLEGO/slegospace/knowledgespace'

if is_colab_runtime()==True:
  from google.colab import files
  files.view(folder_path)
os.chdir(folder_path)

# %% [markdown]
# # Import Libraries
# Import all the related libraries

# %%
# %%time
import panel as pn
import inspect
import ast  # For safely evaluating the input string
import re
import importlib
import json
import io
import time
import param
import json
from datetime import datetime
import itertools


# if colab or vscode or jupyter
if 'google.colab' in str(get_ipython()):
    pn.extension(comms='colab')
elif 'vscode' in str(get_ipython()):
    pn.extension(comms='vscode')
else:
    print('Unknown runtime environment')
    pn.extension(comms='colab')

pn.extension(sizing_mode = 'stretch_both')
pn.extension('ace', 'jsoneditor')
# Out:
# Unknown runtime environment
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a42f86c4-f451-4832-86b1-6807f98ab3a2'>
#   <div id="b4f476fc-f485-4ae2-939c-5a6cfc4e6783" data-root-id="a42f86c4-f451-4832-86b1-6807f98ab3a2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b9b874f7-c385-45ed-b6e4-d1e8af929397":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a42f86c4-f451-4832-86b1-6807f98ab3a2"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5fab0c74-0d7b-4eea-97f7-1c33f1027611","attributes":{"plot_id":"a42f86c4-f451-4832-86b1-6807f98ab3a2","comm_id":"a954e986a9184d0a93a5f6cf5c25c558","client_comm_id":"b6e29ae1eed04c8798469ca9956f6405"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"b9b874f7-c385-45ed-b6e4-d1e8af929397","roots":{"a42f86c4-f451-4832-86b1-6807f98ab3a2":"b4f476fc-f485-4ae2-939c-5a6cfc4e6783"},"root_ids":["a42f86c4-f451-4832-86b1-6807f98ab3a2"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# CPU times: user 35.1 ms, sys: 5.9 ms, total: 41 ms
# Wall time: 40 ms

# %%
'google.colab' in str(get_ipython())
# Out:
# False

# %% [markdown]
# # Select which modules to import

# %%
# %%time
def delete_func_file(func_file_path):
    # Check if the file exists
    if os.path.exists(func_file_path):
        # Delete the file
        os.remove(func_file_path)
        #print(f"File {func_file_path} has been deleted.")
    else:
        print(f"No file named {func_file_path} found.")


# Step 3: Get the list of .py files in the folder
py_files = [file for file in os.listdir(folder_path+functionspace) if file.endswith('.py')]

# New Step: Check if func.py exists and delete it
func_file_path = 'func.py'
delete_func_file(func_file_path)

funcfilecombo = pn.widgets.MultiChoice(name='Select Function',
                                       value=['util.py',
                                              'func_data_preprocss.py',
                                              'func_moving_avg_plot.py',
                                              'llm.py',
                                              'func_eda.py',
                                              'func_uci_dataset.py',
                                              'webscrape.py',
                                              'func_arxiv.py',
                                              'func_backtest.py',
                                              'func_autogluon.py'],
                                       options=py_files, height=200)

# create funcfilecombo_change function
def funcfilecombo_change(event):
    delete_func_file(func_file_path)

    py_files = funcfilecombo.value
    # Step 4 (Modified): Create a new file named func.py in the current repository
    with open(func_file_path, 'w') as func_file:
        # Step 5: Iterate over each .py file and append its content to func.py
        for py_file in py_files:
            print(py_file)
            file_path = os.path.join(folder_path+functionspace, py_file)
            with open(file_path, 'r') as file:
                func_file.write(file.read() + '\n')
    import func
    importlib.reload(func)


# param watch
funcfilecombo.param.watch(funcfilecombo_change, 'value')

display(funcfilecombo)

# call the event
funcfilecombo_change(None)
# !ls
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# MultiChoice(height=200, name='Select Function', options=['func_autogluon.py', ...], sizing_mode='stretch_width', value=['util.py', 'func_data_pre...])
# No file named func.py found.
# util.py
# func_data_preprocss.py
# func_moving_avg_plot.py
# llm.py
# func_eda.py
# func_uci_dataset.py
# webscrape.py
# func_arxiv.py
# func_backtest.py
# func_autogluon.py
# AutogluonModels        dataspace              knowledgespace
# __pycache__            func.py                recordspace
# ag_multimodal_tutorial functionspace
# CPU times: user 26.9 ms, sys: 16 ms, total: 42.9 ms
# Wall time: 161 ms

# %% [markdown]
# # SLEGO APP

# %%
# %%time
import func
importlib.reload(func)

funccombo = func._create_multi_select_combobox(func)
input_text = pn.widgets.TextAreaInput(value='', placeholder='input the parameters', height=300)
compute_btn = pn.widgets.Button(name='Compute', height =50,  button_type='primary')
savepipe_btn = pn.widgets.Button(name='Save Pipeline', height =35)
pipeline_text= pn.widgets.TextInput(value='', placeholder='Input Pipeline Name', height=35)
json_toggle = pn.widgets.Toggle(name='Input mode: text or form', height =35, button_type='warning')

pipeline_dict = {}
json_editor = pn.widgets.JSONEditor(value=pipeline_dict, height=400, mode='form')
progress_text = pn.widgets.TextAreaInput(value='',placeholder='Input your analytics query here', name='Progress msg and query inputs for recommendation:',height=150)
output_text= pn.widgets.TextAreaInput(value='',placeholder= 'Results will be shown here', name='System output message:')

recommendation_btn = pn.widgets.Button(name='Get Recommendation', height =35, button_type='success')
recomAPI_text= pn.widgets.TextInput(value='', placeholder='Your AI API key', height=35)

# recommendation_btn param watch
def recommendation_btn_clicked(event):
    if event.new:
        output_text.value = 'recommenda clicked'

        func.chatgpt_chat(model='gpt-3.5-turbo',
                  user_input_file='dataspace/user_text_input.txt',
                  output_text_file='dataspace/gpt_output_text.txt',
                  output_json_file='dataspace/gpt_output_full.json',
                  temperature=1,
                  max_tokens=256,
                  top_p=1,
                  frequency_penalty=0,
                  presence_penalty=0,
                  api_key='sk-CiO5GzpXbxZQsMuKEQEkT3BlbkFJz4LS3FuI3f5NqmF1BXO',
                  user_message='[# your query# ], \n generate the pipeline dictionary for me base on my query and input:')

recommendation_btn.param.watch(recommendation_btn_clicked, 'value')


def json_toggle_clicked(event):
    if event.new:
        json_editor.mode= 'text'
    else:
        json_editor.mode= 'form'

json_toggle.param.watch(json_toggle_clicked, 'value')

# json_editor.param.watch(json_editor_change, 'value')



def get_doc_string(pipeline):
    text = input_text.value
    output=''
    data = ast.literal_eval(text)
    data.keys()
    # loop keys
    for key in data.keys():
        output +='#######'+str(key)+'#######\n'
        try:
            output += eval(f'func.{key}.__doc__')+'\n'
        except:
            output += 'No docstring found for this function\n'
    return output

def input_text_change(event):
    global pipeline_dict
    text = re.sub(r'\bfalse\b', 'False', input_text.value, flags=re.IGNORECASE)
    try:
        pipeline_dict = ast.literal_eval(text)
        #json_editor.value = pipeline_dict
        #print(pipeline_dict)
    except ValueError as e:
        output_text.value = f'Error parsing input: {e}'


def funccombo_change(event):
    output_text.value = ''
    list_funcs = funccombo.value
    list_params =[]

    for funcchoice in funccombo.value:
      function=  eval('func.'+funcchoice)
      list_params.append(func._extract_parameter(function))

    funcs_params = dict(zip(list_funcs,list_params))
    formatted_data = json.dumps(funcs_params, indent=5)

    json_editor.value = funcs_params

    input_text.value = str(formatted_data)
    output_text.value = get_doc_string(input_text.value)
    progress_text.value = f'selected {funccombo.value}!'



def save_record(space, data, pipeline_name=None):
    """
    Saves the given data structure as a JSON file named with the current datetime.

    Parameters:
    - data: The data structure to be saved as JSON.
    """
    if pipeline_name is None:
      # Generate a filename based on the current datetime, e.g., "record_20230405_153000.json"
      filename = datetime.now().strftime("record_%Y%m%d_%H%M%S.json")
    else:
      filename = pipeline_name+'.json'

    # Define the full path where you want to save the file, here assuming current directory
    full_path = './'+space+'/' + filename

    # Serialize and save the data structure to a file
    with open(full_path, "w") as file:
        json.dump(data, file, indent=5)


def compute_btn_clicked(event):
    progress_text.value = 'Computing...'
    input_text_change(None)
    time.sleep(1)

    pipeline_dict = json_editor.value
    output_text.value = ''

    for function_name, parameters in pipeline_dict.items():
        progress_text.value = f'Computing {function_name}...'
        module = 'func.'
        start_time = time.time()  # Start the timer

        # Dynamically execute the function
        function = eval(module + function_name)
        result = function(**parameters)
        # Convert result to string
        result_string = str(result)
        # Create an iterator for words
        words_iterator = iter(result_string.split())
        # Use itertools.islice to get the first 1000 words without creating a full list
        first_x_words = itertools.islice(words_iterator, 500)
        # Join the words and append to output_text.value
        # Computation time
        compute_time = time.time() - start_time

        output_text.value += f"\n===================={function_name}====================\n\n"
        output_text.value += f"Function computation Time: {compute_time:.4f} seconds\n"
        output_text.value += f"\n"
        output_text.value += " ".join(first_x_words)

    save_record('recordspace', pipeline_dict)
    progress_text.value = 'Done!'

def save_pipeline(event):
    if pipeline_text.value == '':
      pipeline_name = '__'
    else:
      pipeline_name = pipeline_text.value
    text = input_text.value
    text = re.sub(r'\bfalse\b', 'False', input_text.value, flags=re.IGNORECASE)
    data = ast.literal_eval(text)
    save_record('knowledgespace', data, pipeline_name)

# save output into specific folder
funccombo.param.watch(funccombo_change, 'value')
input_text.param.watch(input_text_change, 'value')

compute_btn.on_click(compute_btn_clicked)
savepipe_btn.on_click(save_pipeline)


app = pn.Row(pn.Column(funccombo,compute_btn,pn.Row(savepipe_btn,pipeline_text,json_toggle), json_editor ), pn.Column(pn.Row(recommendation_btn,recomAPI_text),progress_text,pn.layout.Divider(height=10,margin=(10)),output_text))
# Out:
# CPU times: user 8.46 ms, sys: 2.48 ms, total: 10.9 ms
# Wall time: 10.1 ms

# %% [markdown]
# # Display the App

# %%
# sk-proj-YhVTgCpkaPhfnwTrPZ3YT3BlbkFJWaQDSe0cSC0OfT0X6WK
app
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row(sizing_mode='stretch_both')
#     [0] Column(sizing_mode='stretch_both')
#         [0] MultiChoice(height=150, name='Functions:', options=['autogluon_model_predict'...], sizing_mode='stretch_width')
#         [1] Button(button_type='primary', height=50, name='Compute', sizing_mode='stretch_width')
#         [2] Row(sizing_mode='stretch_both')
#             [0] Button(height=35, name='Save Pipeline', sizing_mode='stretch_width')
#             [1] TextInput(height=35, placeholder='Input Pipeline Name', sizing_mode='stretch_width')
#             [2] Toggle(button_type='warning', height=35, name='Input mode: t..., sizing_mode='stretch_width')
#         [3] JSONEditor(height=400, mode='form', sizing_mode='stretch_width')
#     [1] Column(sizing_mode='stretch_both')
#         [0] Row(sizing_mode='stretch_both')
#             [0] Button(button_type='success', height=35, name='Get Recommendation', sizing_mode='stretch_width')
#             [1] TextInput(height=35, placeholder='Your AI API key', sizing_mode='stretch_width')
#         [1] TextAreaInput(height=150, name='Progress msg a..., placeholder='Input your analytics q..., sizing_mode='stretch_width')
#         [2] Divider(height=10, margin=10, sizing_mode='stretch_width')
#         [3] TextAreaInput(name='System output message:', placeholder='Results will b..., sizing_mode='stretch_both')
